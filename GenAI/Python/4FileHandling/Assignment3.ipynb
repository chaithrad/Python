# %%
# Task1:

sales = [1200, 450,980,1500,3000]

# write to file
file = open("sales_data.txt", "w")
for sale in sales:
    file.write(f"{sale}\n")
file.close()

# read from file
file = open("sales_data.txt", "r")
sales_data = file.read()
print("Sales data read from file:")
print(sales_data)
file.close()

""" # Using with 
# write to file
with open('sales_data.txt', 'w') as f:
    for sale in sales:
        f.write(f"{sale}\n")

# open and read the file
with open('sales_data.txt', 'r') as f:
    sales_data = f.read()
    print("Sales data read from file:")
    print(sales_data) """
# Out:
# Sales data read from file:
# 1200
# 450
# 980
# 1500
# 3000
# ' # Using with \n# write to file\nwith open(\'sales_data.txt\', \'w\') as f:\n    for sale in sales:\n        f.write(f"{sale}\n")\n\n# open and read the file\nwith open(\'sales_data.txt\', \'r\') as f:\n    sales_data = f.read()\n    print("Sales data read from file:")\n    print(sales_data) '

# %%
# Task2:
#1. using .read()
file = open("sales_data.txt", "r")
sales_data = file.read()
print("Sales data read from file using .read():")
print(sales_data)
file.close()

#2. using .readline()
file = open("sales_data.txt", "r")  
sales_data = file.readline()
print("First line of sales data read from file using .readline():")
print(sales_data)
file.close()

#3. using .readlines()
file = open("sales_data.txt", "r")
sales_data = file.readlines()   
print("All lines of sales data read from file using .readlines():")
print(sales_data)
file.close()

''' #3.1 using clean formate:
file = open("sales_data.txt", "r")
lines = file.readlines()
sales = []
for line in lines:
    sales.append(int(line.strip()))
file.close()
print("All line sales data converted to integers:")
print(sales) '''
# Out:
# Sales data read from file using .read():
# 1200
# 450
# 980
# 1500
# 3000
#
# First line of sales data read from file using .readline():
# 1200
#
# All lines of sales data read from file using .readlines():
# ['1200\n', '450\n', '980\n', '1500\n', '3000\n']
# ' #3.1 using clean formate:\nfile = open("sales_data.txt", "r")\nlines = file.readlines()\nsales = []\nfor line in lines:\n    sales.append(int(line.strip()))\nfile.close()\nprint("All line sales data converted to integers:")\nprint(sales) '

# %%
# Task3:
new_sales = [1200, 450,980,1500,3000,5000,2500,1700]
# write to file 
file = open("sales_data.txt", "w")

for sale in new_sales:
    file.write(f"{sale}\n")
file.close()

# read the file
file = open("sales_data.txt", "r")
sales_data = file.read()
print("Updated sales data read from file:")
print(sales_data)
file.close

file = open("sales_data.txt", "r")
lines = file.readlines()
print("Number of lines in the file:", len(lines))
file.close()
# Out:
# Updated sales data read from file:
# 1200
# 450
# 980
# 1500
# 3000
# 5000
# 2500
# 1700
#
# Number of lines in the file: 8

# %%
#task4:
file = open("sales_data.txt", "r")
sales_data = file.readlines()
sales = []
for line in sales_data:
    sales.append(int(line.strip()))
file.close()

total_sales = sum(sales)
print("Total Sales:", total_sales)
highest_sale = max(sales)
print("Highest Sale:", highest_sale)
lowest_sale = min(sales)
print("Lowest Sale:", lowest_sale)
average_sale = total_sales / len(sales)
print("Average Sale:", average_sale)
# Out:
# Total Sales: 16330
# Highest Sale: 5000
# Lowest Sale: 450
# Average Sale: 2041.25

# %%
#task5:
file = open("products.txt", "w")
for i in range(3):
    product_name = input(f"Enter the product name: ")
    product_price = input(f"Enter the product price: ")
    file.write(f"{product_name} | {product_price}\n")
file.close()

# raed filw
file = open("products.txt", "r")
lines = file.readlines()
for line in lines:
    print(line.strip())
file.close()
# Out:
# hair drier | 2000
# charger | 500
# laptop | 50000

# %%
#Task6:
import os
filename = input("Enter the filename: ")

if os.path.exists(filename):
    file = open(filename, "r")
    content = file.read()
    print("\nFile contents:")
    print(content)
    file.close()
else:
    print("File not found. Please check the filename.")
# Out:
# File not found. Please check the filename.

# %%
# task7:
prices = {"Mouse": 500,"Keyboard": 800,"Monitor": 7000,"Pendrive": 400,"Camera": 5000}
discount = float(input("Enter discount percentage: "))

file = open("discount_report.txt", "w")
file.write("Product | Original Price | Discounted Price\n")
discounted_prices = []

for product in prices:
    original_price = prices[product]
    discount_amount = original_price * discount / 100
    discounted_price = original_price - discount_amount
    discounted_prices.append(discounted_price)
    file.write(f"{product} | {original_price} | {discounted_price}\n"
    )

total_items = len(discounted_prices)
average_discounted_price = sum(discounted_prices) / total_items

file.write(f"\nTotal Items: {total_items}\n")
file.write(f"Average Discounted Price: {average_discounted_price}\n")
file.close()

# Read the report
file = open("discount_report.txt", "r")
content = file.read()
print("\nDiscount Report:")
print(content)
file.close()
# Out:
# Discount Report:
# Product | Original Price | Discounted Price
# Mouse | 500 | 475.0
# Keyboard | 800 | 760.0
# Monitor | 7000 | 6650.0
# Pendrive | 400 | 380.0
# Camera | 5000 | 4750.0
#
# Total Items: 5
# Average Discounted Price: 2603.0
