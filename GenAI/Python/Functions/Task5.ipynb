# %%
# uisng filter()
prices = [100, 250, 400, 1200, 50,2000,850]

expensive_items = list(filter(lambda price: price > 500, prices))
cheap_items = list(filter(lambda price: price <= 500, prices))

print("Original Prices:", prices)
print("Expensive Items:", expensive_items)
print("Cheap Items:", cheap_items)
# Out:
# Original Prices: [100, 250, 400, 1200, 50, 2000, 850]
# Expensive Items: [1200, 2000, 850]
# Cheap Items: [100, 250, 400, 50]
