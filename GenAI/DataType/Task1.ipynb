# %%
# 1. create a list of products
products = ["Laptop", "Smartphone", "Tablet", "Headphones", "Smartwatch","Camera"]
# 2. create tupples
sample_products = ("Laptop", 55000,"Electronics")
# 3. print the 2md and last product
print("Second product:", products[1])
print("Last product:", products[-1])
# 4. Append a new product to the list
products.append("monitor")
products.append("Tablet")
print("Updated product list:", products)
# 5. Extra : convert tupple to list, change price and convert back 
sample_products_list = list(sample_products)
sample_products_list[1] = 60000  # Change the price
sample_products = tuple(sample_products_list)  # Convert back to tuple
print("Updated sample products:", sample_products)
